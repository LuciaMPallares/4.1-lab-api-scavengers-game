# %%
import json
import requests

# %%
# %pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
# Out:
# False

# %% [markdown]
# Only if you're using your environmental variable eith the `.env` file, import/install the following modules. Otherwise it is not necessary:
#
# https://pypi.org/project/python-dotenv/

# %%
import os
from dotenv import load_dotenv

# %%
#pip install python-dotenv

# %%
load_dotenv()
# Out:
# False

# %%
github = os.getenv("token")

# %% [markdown]
# empezamos aqui el ejercicio

# %%
with open(r'C:\Users\USER\Documents\Lucía\Ironhack\Bootcamp\Semana4\4.1-lab-api-scavengers-game\your-code\token.txt', 'r') as f:
    token = f.read()

# %%
token
# Out:
# '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\n\n'

# %% [markdown]
# # Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/datamad1020-rev, you will:
#
# 1. Obtain the full list of forks created from the main lab repo via Github API.
#
# 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
# Hint: Each language should appear only once in your array.
#
# 3. Print the language array. It should be something like:
#
# ["Python", "Jupyter Notebook", "HTML"]

# %% [markdown]
# **HINT:**: Create a list with every **language_url** you find in every fork

# %% [markdown]
# ⚠️ **Remember to limit your output before submission**.

# %%
url ='https://api.github.com/repos/Ironhack-Data-Madrid-Agosto-2022/3.4-lab-mongo/forks' #buscamos en el link de hithub

# %%
response=requests.get(url)

response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# [{'id': 561475587,
#   'node_id': 'R_kgDOIXdwAw',
#   'name': '3.4-lab-mongo',
#   'full_name': 'Rmp2/3.4-lab-mongo',
#   'private': False,
#   'owner': {'login': 'Rmp2',
#    'id': 114113071,
#    'node_id': 'U_kgDOBs06Lw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/114113071?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rmp2',
#    'html_url': 'https://github.com/Rmp2',
#    'followers_url': 'https://api.github.com/users/Rmp2/followers',
#    'following_url': 'https://api.github.com/users/Rmp2/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Rmp2/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Rmp2/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Rmp2/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Rmp2/orgs',
#    'repos_url': 'https://api.github.com/users/Rmp2/repos',
# ...

# %%
import pandas as pd

df=pd.DataFrame(response)

df.head(5)
# Out:
#           id       node_id           name                     full_name  \
# 0  561475587  R_kgDOIXdwAw  3.4-lab-mongo            Rmp2/3.4-lab-mongo
# 1  561348905  R_kgDOIXWBKQ  3.4-lab-mongo        kranieel/3.4-lab-mongo
# 2  561296661  R_kgDOIXS1FQ  3.4-lab-mongo     FrankOballe/3.4-lab-mongo
# 3  561292709  R_kgDOIXSlpQ  3.4-lab-mongo  LuciaMPallares/3.4-lab-mongo
# 4  561292625  R_kgDOIXSlUQ  3.4-lab-mongo       Jorlo0412/3.4-lab-mongo
#
#    private                                              owner  \
# 0    False  {'login': 'Rmp2', 'id': 114113071, 'node_id': ...
# 1    False  {'login': 'kranieel', 'id': 112859701, 'node_i...
# 2    False  {'login': 'FrankOballe', 'id': 114352562, 'nod...
# 3    False  {'login': 'LuciaMPallares', 'id': 114522768, '...
# 4    False  {'login': 'Jorlo0412', 'id': 114603199, 'node_...
#
#                                           html_url description  fork  \
# 0            https://github.com/Rmp2/3.4-lab-mongo        None  True
# ...

# %%
print(df.columns)
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
#iteramos sobre todos los elementos de response y ponemos.json para hacer una lista de diccionarios
#añade en lista cada i que ha pasado por la key language de responso.json

# %%
lista = []                      
for i in range(len(response.json())):
    lista.append(response.json()[i]['language'])

print(lista)
# Out:
# ['Jupyter Notebook', None, 'Jupyter Notebook', 'Jupyter Notebook', None, 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook']

# %%
set(lista)  #El tipo set en Python es la clase utilizada por el lenguaje para representar los conjuntos. 
             #Un conjunto es una colección desordenada de elementos únicos, es decir, que no se repiten.
# Out:
# {'Jupyter Notebook', None}
